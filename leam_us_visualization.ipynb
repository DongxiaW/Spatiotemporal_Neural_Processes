# %%
import pandas as pd
import numpy as np
import us as usStates

from numpy import savetxt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import sys
np.set_printoptions(threshold=sys.maxsize)
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn import datasets
import glob

# %% [markdown]
# start

# %%
np_lig1_0_df = pd.read_csv("../result_lig1/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig1_1_df = pd.read_csv("../result_lig1/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig1_2_df = pd.read_csv("../result_lig1/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig1_0 = np_lig1_0_df['test_MAE'].values
np_lig1_1 = np_lig1_1_df['test_MAE'].values
np_lig1_2 = np_lig1_2_df['test_MAE'].values

# %%
np_lig2_0_df = pd.read_csv("../result_lig2/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig2_1_df = pd.read_csv("../result_lig2/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig2_2_df = pd.read_csv("../result_lig2/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig2_0 = np_lig2_0_df['test_MAE'].values
np_lig2_1 = np_lig2_1_df['test_MAE'].values
np_lig2_2 = np_lig2_2_df['test_MAE'].values

# %%
np_lig4_0_df = pd.read_csv("../result_lig4/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig4_1_df = pd.read_csv("../result_lig4/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig4_2_df = pd.read_csv("../result_lig4/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig4_0 = np_lig4_0_df['test_MAE'].values
np_lig4_1 = np_lig4_1_df['test_MAE'].values
np_lig4_2 = np_lig4_2_df['test_MAE'].values

# %%
np_lig8_0_df = pd.read_csv("../result_lig8/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig8_1_df = pd.read_csv("../result_lig8/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig8_2_df = pd.read_csv("../result_lig8/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_lig8_0 = np_lig8_0_df['test_MAE'].values
np_lig8_1 = np_lig8_1_df['test_MAE'].values
np_lig8_2 = np_lig8_2_df['test_MAE'].values

# %%
np_maxentropy_0_df = pd.read_csv("../result_maxentropy/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_maxentropy_1_df = pd.read_csv("../result_maxentropy/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_maxentropy_2_df = pd.read_csv("../result_maxentropy/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_maxentropy_0 = np_maxentropy_0_df['test_MAE'].values
np_maxentropy_1 = np_maxentropy_1_df['test_MAE'].values
np_maxentropy_2 = np_maxentropy_2_df['test_MAE'].values

# %%
np_meanstd_0_df = pd.read_csv("../result_meanstd/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_meanstd_1_df = pd.read_csv("../result_meanstd/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_meanstd_2_df = pd.read_csv("../result_meanstd/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_meanstd_0 = np_meanstd_0_df['test_MAE'].values
np_meanstd_1 = np_meanstd_1_df['test_MAE'].values
np_meanstd_2 = np_meanstd_2_df['test_MAE'].values

# %%
np_random_0_df = pd.read_csv("../result_random/metric_seed0.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_random_1_df = pd.read_csv("../result_random/metric_seed1.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_random_2_df = pd.read_csv("../result_random/metric_seed2.csv", names=['val_MAE', 'test_MAE', 'test_RMSE'])
np_random_0 = np_random_0_df['test_MAE'].values
np_random_1 = np_random_1_df['test_MAE'].values
np_random_2 = np_random_2_df['test_MAE'].values

# %%
np_lig1 = np.mean(np.stack([np_lig1_0,np_lig1_1,np_lig1_2],0),0)
np_lig2 = np.mean(np.stack([np_lig2_0,np_lig2_1,np_lig2_2],0),0)
np_lig4 = np.mean(np.stack([np_lig4_0,np_lig4_1,np_lig4_2],0),0)
np_lig8 = np.mean(np.stack([np_lig8_0,np_lig8_1,np_lig8_2],0),0)
np_random = np.mean(np.stack([np_random_0,np_random_1,np_random_2],0),0)
np_maxentropy = np.mean(np.stack([np_maxentropy_0,np_maxentropy_1,np_maxentropy_2],0),0)
np_meanstd = np.mean(np.stack([np_meanstd_0,np_meanstd_1,np_meanstd_2],0),0)

# %%
std_lig1 = np.std(np.stack([np_lig1_0,np_lig1_1,np_lig1_2],0),0)
std_lig2 = np.std(np.stack([np_lig2_0,np_lig2_1,np_lig2_2],0),0)
std_lig4 = np.std(np.stack([np_lig4_0,np_lig4_1,np_lig4_2],0),0)
std_lig8 = np.std(np.stack([np_lig8_0,np_lig8_1,np_lig8_2],0),0)
std_random = np.std(np.stack([np_random_0,np_random_1,np_random_2],0),0)
std_maxentropy = np.std(np.stack([np_maxentropy_0,np_maxentropy_1,np_maxentropy_2],0),0)
std_meanstd = np.std(np.stack([np_meanstd_0,np_meanstd_1,np_meanstd_2],0),0)

# %%
print(np_random_update)
# Out:
# [90195.40933333 20960.90966667 13417.81166667 12490.80566667
#  11073.07466667  9331.98833333  8769.721       8076.806
#   8076.806       7498.719       7108.27896667  6718.50866667]

# %%
#interpolation flip calculate sample efficiency
x_lig = np.flip(np_lig8)
np_random_update = np_random
np_random_update[-5] = np_random_update[-4]+1
x_random = np.flip(np_random_update)
y = np.flip(np.linspace(27,115,12))
print(np.all(np.diff(x_lig) > 0), np.all(np.diff(x_random) > 0))
print(x_lig)
print((np.interp(6008.09*2, x_random, y)-np.interp(6008.09*2, x_lig, y))/np.interp(6008.09*2, x_random, y))
print((np.interp(6008.09*3, x_random, y)-np.interp(6008.09*3, x_lig, y))/np.interp(6008.09*3, x_random, y))
# print((np.interp(6008.09*4, x_random, y)-np.interp(6008.09*4, x_lig, y))/np.interp(6008.09*4, x_random, y))
# Out:
# True True
# [ 6008.09003333  6010.5733      6217.18393333  6539.32
#   7106.9298      7286.58283333  7592.88166667  9191.29
#  10223.688      11703.69266667 14446.62033333 96200.93      ]
# 0.21590923438258197
# 0.09089991051326465

# %%
print(np.mean(np.array(((np_random-np_lig8)/np_random)[1:])))
print(np.array(((np_random-np_lig8)/np_random)[1:]))
# Out:
# 0.16805502899844577
# [0.31078276 0.12774952 0.18150292 0.16994238 0.18635971 0.16912034
#  0.0817221  0.19035817 0.17090053 0.15442636 0.10574052]

# %%
print(np_random, std_random)
# Out:
# [90195.40933333 20960.90966667 13417.81166667 12490.80566667
#  11073.07466667  9331.98833333  8769.721       7739.41073333
#   8076.806       7498.719       7108.27896667  6718.50866667] [57397.68714696  5548.06843633   815.45730944   417.78429563
#    479.06728354   600.87125421   781.12405653   614.20606679
#    657.31116      314.94979239   491.28543193   382.58020507]

# %%
print(np_meanstd, std_meanstd)
# Out:
# [104613.092       35356.81133333  16091.62        12723.749
#   12534.44566667  11191.17633333  10284.81516667   9266.462
#    7908.45233333   7924.934        7783.56053333   7533.0405    ] [45965.64396765 28706.9072006   3110.40510229   137.50179594
#    178.95077307   183.69147678   700.02801815   768.15739702
#    535.68666322   560.4322686    541.46327488   860.99813729]

# %%
print(np_maxentropy, std_maxentropy)
# Out:
# [101585.65233333  65498.272       30495.89733333  12881.34366667
#   10828.7675      10028.38433333  10686.35433333  10831.74983333
#    8417.17066667   7876.0413       7783.9357       7430.56633333] [48958.95925884 13324.36871578 24333.23556165   752.59686643
#   1174.34858118  2065.22470659  2491.43657882  2834.24863128
#    616.10894097   805.13394701   985.63269534   775.60771286]

# %%
print(np_lig8, std_lig8)
# Out:
# [96200.93       14446.62033333 11703.69266667 10223.688
#   9191.29        7592.88166667  7286.58283333  7106.9298
#   6539.32        6217.18393333  6010.5733      6008.09003333] [52635.94049361  1086.5037667    216.00339009   613.80350886
#    928.280517     822.28982021   670.60947198   850.38346599
#    618.09755737   481.3912912    672.79902115  1079.27881891]

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': med,
          'legend.fontsize': 20,
          'figure.figsize': (18, 10),
          'axes.labelsize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': med}
plt.rcParams.update(params)

# %%
fig, axs = plt.subplots(1,1) #(1,3)

t = np.arange(1,13)

axs.plot(t, np_lig8[:],'*-',color='r',ms=10, label = 'LIG')
axs.plot(t, np_random[:],'bo--',ms=10, label = 'Random')
axs.plot(t, np_maxentropy[:],'gs-.',ms=10, label = 'MaxEntropy')
axs.plot(t, np_meanstd[:],linestyle='dotted',marker='v',ms=10,color='purple',label='MeanSTD')

axs.plot(t, np.ones(12)*(5473.896+5938.912+7458.7925)/3,'--',color='k',ms=10, label = 'Offline')
axs.set_ylabel('MAE',fontsize=25)
axs.set_xlabel('Percentage of Data', fontsize=25)
axs.grid()
axs.set_xticks(range(1,13))
axs.set_xticklabels(('8.6%','11.1%','13.7%','16.2%','18.7%','21.3%','23.8%','26.3%','28.9%','31.4%','34%','36.5%'))
axs.set_yscale('log')
# axs.legend()
axs.legend(prop={'size': 18})
plt.savefig('../figure/LEAM_ac_comp.pdf')

# %%
fig, axs = plt.subplots(1,1) #(1,3)

t = np.arange(1,13)

axs.plot(t, np_lig1[:],linestyle='-',marker='*',ms=10,color='purple',label='Batch Size 1')
axs.plot(t, np_lig2[:],'g*-',ms=10, label = 'Batch Size 2')
axs.plot(t, np_lig4[:],'b*-',ms=10, label = 'Batch Size 4')
axs.plot(t, np_lig8[:],'*-',color='r',ms=10, label = 'Batch Size 8')
axs.plot(t, np.ones(12)*(5473.896+5938.912+7458.7925)/3,'--',color='k',ms=10, label = 'Offline')
axs.set_ylabel('MAE',fontsize=25)
axs.set_xlabel('Percentage of Data', fontsize=25)
axs.grid()
axs.set_xticks(range(1,13))
axs.set_xticklabels(('8.6%','11.1%','13.7%','16.2%','18.7%','21.3%','23.8%','26.3%','28.9%','31.4%','34%','36.5%'))
axs.set_yscale('log')
axs.legend()
plt.savefig('../figure/LEAM_lig_ablation.pdf')

# %%
fig, axs = plt.subplots(1,1) #(1,3)

t = np.arange(1,13)

axs.plot(t, np_lig1[:],linestyle='dotted',marker='v',ms=10,color='purple',label='Batch Size 1')
axs.plot(t, np_lig2[:],'gs-.',ms=10, label = 'Batch Size 2')
axs.plot(t, np_lig4[:],'bo--',ms=10, label = 'Batch Size 4')
axs.plot(t, np_lig8[:],'*-',color='r',ms=10, label = 'Batch Size 8')
axs.plot(t, np.ones(12)*(5473.896+5938.912+7458.7925)/3,'--',color='k',ms=10, label = 'Offline')
axs.set_ylabel('MAE',fontsize=25)
axs.set_xlabel('Percentage of Data', fontsize=25)
axs.grid()
axs.set_xticks(range(1,13))
axs.set_xticklabels(('8.6%','11.1%','13.7%','16.2%','18.7%','21.3%','23.8%','26.3%','28.9%','31.4%','34%','36.5%'))
axs.set_yscale('log')
axs.legend()
plt.savefig('../figure/LEAM_lig_ablation.pdf')
